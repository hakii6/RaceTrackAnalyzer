# %%
from PIL import Image 
import numpy

import json

import math

track = {
    'distance': 3200
}

base_speed = 18.8


for i_100 in range(1, 24):
    i = i_100 * 50
    int_top = (i / 5500) * math.log(i * 0.1, 10) / 100
    int_bottom = ((i / 5500) * math.log(i * 0.1, 10) - 0.65) / 100
    print(int_top, int_bottom)
    print(i, base_speed * (1 + int_top), base_speed * (1 + int_bottom))
    print()
# Out:
# 6.354272766691079e-05 -0.00643645727233309
# 50 18.80119460328014 18.678994603280138
#
# 0.0001818181818181818 -0.006318181818181818
# 100 18.803418181818184 18.681218181818185
#
# 0.00032075216156064024 -0.00617924783843936
# 150 18.806030140637343 18.68383014063734
#
# 0.000473101816605084 -0.006026898183394917
# 200 18.808894314152177 18.686694314152174
#
# 0.000635427276669108 -0.005864572723330892
# 250 18.81194603280138 18.68974603280138
#
# 0.0008057025025743612 -0.005694297497425639
# 300 18.815147207048398 18.692947207048398
#
# 0.0009825887554956298 -0.0055174112445043715
# 350 18.81847266860332 18.69627266860332
#
# 0.001165134539147609 -0.005334865460852391
# 400 18.821904529335978 18.699704529335975
#
# 0.0013526284203616446 -0.005147371579638356
# 450 18.825429414302796 18.7032294143028
#
# 0.001544518185760017 -0.004955481814239984
# 500 18.82903694189229 18.706836941892288
#
# 0.0017403626894942439 -0.004759637310505756
# 550 18.832718818562494 18.71051881856249
#
# ...

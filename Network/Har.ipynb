# %%
import json
import base64
from haralyzer import HarParser, HarPage


with open('gamewith.jp3.har', 'r', encoding='utf8') as f:
    har_parser = HarParser(json.loads(f.read()))
    
data = har_parser.har_data
# print(data.keys())
# print(data['version'])
# print(data['creator'])
# print(data['pages'])
# print(data['entries'][0])

for entry in data["entries"]:
#     print(entry.keys())
#     print(entry["request"])
#     request = entry["request"]
#     print(request.keys(), "\n")
#     print("queryString:\n", request["queryString"])
#     for header in request["headers"]:
#         print(header)
        
    response = entry["response"]
#     print("response:\n", response.keys(), "\n")
#     print("\n")
#     for key in response:
#         print(key, ": ", response[key])
#     for header in response["headers"]:
#         print(header)
        
    content = response["content"]

    
    if content["mimeType"] == "image/png":
        continue
    print("--------------")
    print(response)
    print("\n")
    for key in content:
        print(key, ": ", content[key])
    
#     print("text: ", text)
#     print(text.encode("utf8"))
    text_bytes = text.encode()
    
#     print(text_bytes.decode("utf8"))
#     print(text.decode("utf-8").encode("utf8"))
    
    
#     print(message)
#     for content in response["content"]:
#         print(content)
#     print(entry["response"])
# Out:
# --------------
# ...

# %%
import requests

curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&VER=8&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&SID=F_veoOLVRAfSdRiKKlKcAw&RID=58633&AID=204&zx=wxa3uu16yfev&t=1" ^
  -H "authority: firestore.googleapis.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: application/x-www-form-urlencoded" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --data-raw "count=1&ofs=2&req0___data__=^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22addTarget^%^22^%^3A^%^7B^%^22query^%^22^%^3A^%^7B^%^22structuredQuery^%^22^%^3A^%^7B^%^22from^%^22^%^3A^%^5B^%^7B^%^22collectionId^%^22^%^3A^%^22umaMusumeFriends^%^22^%^7D^%^5D^%^2C^%^22where^%^22^%^3A^%^7B^%^22fieldFilter^%^22^%^3A^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22factorIds^%^22^%^7D^%^2C^%^22op^%^22^%^3A^%^22ARRAY_CONTAINS_ANY^%^22^%^2C^%^22value^%^22^%^3A^%^7B^%^22arrayValue^%^22^%^3A^%^7B^%^22values^%^22^%^3A^%^5B^%^7B^%^22integerValue^%^22^%^3A^%^223^%^22^%^7D^%^5D^%^7D^%^7D^%^7D^%^7D^%^2C^%^22orderBy^%^22^%^3A^%^5B^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22updatedAt^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^2C^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22__name__^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^5D^%^2C^%^22limit^%^22^%^3A200^%^7D^%^2C^%^22parent^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^2Fdocuments^%^22^%^7D^%^2C^%^22targetId^%^22^%^3A4^%^7D^%^7D" ^
  --compressed &
curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&VER=8&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&SID=F_veoOLVRAfSdRiKKlKcAw&RID=58634&AID=408&zx=43qa7ttsmtxo&t=1" ^
  -H "authority: firestore.googleapis.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: application/x-www-form-urlencoded" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --data-raw "count=1&ofs=3&req0___data__=^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22removeTarget^%^22^%^3A4^%^7D" ^
  --compressed &
curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&VER=8&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&SID=F_veoOLVRAfSdRiKKlKcAw&RID=58635&AID=408&zx=7n8bkvrk8ui0&t=1" ^
  -H "authority: firestore.googleapis.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: application/x-www-form-urlencoded" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --data-raw "count=1&ofs=4&req0___data__=^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22addTarget^%^22^%^3A^%^7B^%^22query^%^22^%^3A^%^7B^%^22structuredQuery^%^22^%^3A^%^7B^%^22from^%^22^%^3A^%^5B^%^7B^%^22collectionId^%^22^%^3A^%^22umaMusumeFriends^%^22^%^7D^%^5D^%^2C^%^22where^%^22^%^3A^%^7B^%^22fieldFilter^%^22^%^3A^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22factorIds^%^22^%^7D^%^2C^%^22op^%^22^%^3A^%^22ARRAY_CONTAINS_ANY^%^22^%^2C^%^22value^%^22^%^3A^%^7B^%^22arrayValue^%^22^%^3A^%^7B^%^22values^%^22^%^3A^%^5B^%^7B^%^22integerValue^%^22^%^3A^%^227^%^22^%^7D^%^5D^%^7D^%^7D^%^7D^%^7D^%^2C^%^22orderBy^%^22^%^3A^%^5B^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22updatedAt^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^2C^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22__name__^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^5D^%^2C^%^22limit^%^22^%^3A200^%^7D^%^2C^%^22parent^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^2Fdocuments^%^22^%^7D^%^2C^%^22targetId^%^22^%^3A6^%^7D^%^7D" ^
  --compressed &
curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&VER=8&RID=rpc&SID=F_veoOLVRAfSdRiKKlKcAw&CI=0&AID=409&TYPE=xmlhttp&zx=cjze1cz307dw&t=2" ^
  -H "authority: firestore.googleapis.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --compressed &
curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&VER=8&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&SID=F_veoOLVRAfSdRiKKlKcAw&RID=58636&AID=612&zx=kbsgtk9l77ii&t=1" ^
  -H "authority: firestore.googleapis.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: application/x-www-form-urlencoded" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --data-raw "count=1&ofs=5&req0___data__=^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22removeTarget^%^22^%^3A6^%^7D" ^
  --compressed &
curl "https://img.gamewith.jp/article_tools/uma-musume/gacha/i_22.png" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  --compressed &
curl "https://analytics.google.com/g/collect?v=2&tid=G-PHTF4DYVJD&gtm=2oe5j0&_p=691340516&sr=1920x1080&ul=en-us&cid=1460352658.1616650588&dl=https^%^3A^%^2F^%^2Fgamewith.jp^%^2Fuma-musume^%^2Farticle^%^2Fshow^%^2F260740&dt=^%^E3^%^80^%^90^%^E3^%^82^%^A6^%^E3^%^83^%^9E^%^E5^%^A8^%^98^%^E3^%^80^%^91^%^E3^%^83^%^95^%^E3^%^83^%^AC^%^E3^%^83^%^B3^%^E3^%^83^%^89^%^E5^%^8B^%^9F^%^E9^%^9B^%^86^%^E6^%^8E^%^B2^%^E7^%^A4^%^BA^%^E6^%^9D^%^BF^%^EF^%^BD^%^9C^%^E6^%^98^%^9F3^%^E5^%^9B^%^A0^%^E5^%^AD^%^90^%^EF^%^BC^%^86^%^E5^%^AE^%^8C^%^E5^%^87^%^B8^%^E7^%^B5^%^9E^%^E3^%^82^%^8A^%^E8^%^BE^%^BC^%^E3^%^81^%^BF^%^E6^%^A4^%^9C^%^E7^%^B4^%^A2^%^20-^%^20^%^E3^%^82^%^B2^%^E3^%^83^%^BC^%^E3^%^83^%^A0^%^E3^%^82^%^A6^%^E3^%^82^%^A3^%^E3^%^82^%^BA(GameWith)&uid=&sid=1621902354&sct=28&seg=1&_s=4" ^
  -H "authority: analytics.google.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain;charset=UTF-8" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: no-cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "cookie: __Secure-3PAPISID=FzkGt7OGmii9_Sq8/Ax06TZh62AFMxURd5; ANID=AHWqTUn0VtbSrzH80mGhK04bF-5eu2dJAS2vHDBlTA-9IkFRRZJ2h08SDBfc6cU8; __Secure-3PSID=9gdneAUsSgoruYQSMMNV5h_hQgVQC28xeASOGZzTEV8rfhkJQ4bq3XDndM-4pLin3GGoGA.; NID=216=hSKTRsAIGQBsLw3DNrUQ0J8nT8rw03wSSaCpcou5HrnbtMXNDD1Ime0ZaQYRQcbiNZJsLEhBlme4OB-_4ESYDpWE8i0IFyfQ_5mT5KTzD0kr4PHUDypeGW7IJDGVP2lmEZpmFGcM3c-OZ6FUER_DBb6CZsdbgDSaXQP_MM99_GjTf7uagotCXinwqEfp_9nJ5LZdtxsXzcoSf-2JJl5clILBTKeY7erx3nr57fQa56HUT9JOSPUbZisv9e3inrhEzbz2w-S87X2bdj8m; 1P_JAR=2021-05-25-01; __Secure-3PSIDCC=AJi4QfGDxrCawbK0Te5K0SGruQ7Hw29G8FZ5S5vWVppYJSBDzbGbePgwjJE78LEXv0fZZSCPodF6" ^
  --data-raw ^"en=Walkthrough_Click_Event&_et=6802&ep.name=^%^E3^%^82^%^A6^%^E3^%^83^%^9E^%^E5^%^A8^%^98^%^E3^%^83^%^95^%^E3^%^83^%^AC^%^E3^%^83^%^B3^%^E3^%^83^%^89^%^E6^%^8E^%^B2^%^E7^%^A4^%^BA^%^E6^%^9D^%^BF&ep.type=^%^E6^%^A4^%^9C^%^E7^%^B4^%^A2^%^E3^%^83^%^9C^%^E3^%^82^%^BF^%^E3^%^83^%^B3^

en=uma-friend-search&_et=6&ep.support-card=&ep.limit=&ep.status=^%^E3^%^83^%^91^%^E3^%^83^%^AF^%^E3^%^83^%^BC&ep.distance=^%^E3^%^83^%^80^%^E3^%^83^%^BC^%^E3^%^83^%^88&ep.unique=&ep.common=&ep.race=&ep.paging=1&ep.main-umamusume=^" ^
  --compressed &
curl "https://bam.nr-data.net/jserrors/1/31f1428de6?a=564273353&v=1208.49599aa&to=blVRYxRWWEpWVBdZC1cfcEIVQ1lUGFYRRA1aXFYYFV9ZThgd&rst=76875&ck=1&ref=https://gamewith.jp/uma-musume/article/show/260740" ^
  -H "Connection: keep-alive" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain" ^
  -H "Accept: */*" ^
  -H "Origin: https://gamewith.jp" ^
  -H "Sec-Fetch-Site: cross-site" ^
  -H "Sec-Fetch-Mode: cors" ^
  -H "Sec-Fetch-Dest: empty" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "Cookie: JSESSIONID=2911db6d88cfa1eb" ^
  --data-raw "^{^\^"xhr^\^":^[^{^\^"params^\^":^{^\^"method^\^":^\^"GET^\^",^\^"host^\^":^\^"currency.prebid.org:443^\^",^\^"pathname^\^":^\^"/latest.json^\^",^\^"status^\^":0^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"duration^\^":^{^\^"t^\^":4^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":932^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"www.google-analytics.com:443^\^",^\^"pathname^\^":^\^"/j/collect^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"rxSize^\^":^{^\^"t^\^":2^},^\^"duration^\^":^{^\^"t^\^":85^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":3522^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"stats.g.doubleclick.net:443^\^",^\^"pathname^\^":^\^"/j/collect^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"rxSize^\^":^{^\^"t^\^":8^},^\^"duration^\^":^{^\^"t^\^":594^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":3606^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"GET^\^",^\^"host^\^":^\^"gamewith-walkthrough-comment-api.akamaized.net:443^\^",^\^"pathname^\^":^\^"/articles/260740/comments^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"rxSize^\^":^{^\^"t^\^":4042^},^\^"duration^\^":^{^\^"t^\^":3102^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":3213^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"GET^\^",^\^"host^\^":^\^"gamewith-walkthrough-comment-api.akamaized.net:443^\^",^\^"pathname^\^":^\^"/articles/260740/comments/count^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"rxSize^\^":^{^\^"t^\^":27^},^\^"duration^\^":^{^\^"t^\^":8077^},^\^"cbTime^\^":^{^\^"t^\^":1^},^\^"time^\^":^{^\^"t^\^":6314^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"bam.nr-data.net:443^\^",^\^"pathname^\^":^\^"/events/1/31f1428de6^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"txSize^\^":^{^\^"t^\^":100^},^\^"rxSize^\^":^{^\^"t^\^":24^},^\^"duration^\^":^{^\^"t^\^":828^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":25140^}^}^}^]^}" ^
  --compressed &
curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&VER=8&RID=rpc&SID=F_veoOLVRAfSdRiKKlKcAw&CI=0&AID=613&TYPE=xmlhttp&zx=sm3o6de1yznj&t=3" ^
  -H "authority: firestore.googleapis.com" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --compressed &
curl "https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&VER=8&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&SID=F_veoOLVRAfSdRiKKlKcAw&RID=58637&TYPE=terminate&zx=ixk3oe98apc0" ^
  -X "POST" ^
  -H "authority: firestore.googleapis.com" ^
  -H "content-length: 0" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain;charset=UTF-8" ^
  -H "accept: */*" ^
  -H "origin: https://gamewith.jp" ^
  -H "x-client-data: CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=" ^
  -H "sec-fetch-site: cross-site" ^
  -H "sec-fetch-mode: no-cors" ^
  -H "sec-fetch-dest: empty" ^
  -H "referer: https://gamewith.jp/" ^
  -H "accept-language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  --compressed &
curl "https://bam.nr-data.net/events/1/31f1428de6?a=564273353&v=1208.49599aa&to=blVRYxRWWEpWVBdZC1cfcEIVQ1lUGFYRRA1aXFYYFV9ZThgd&rst=117223&ck=1&ref=https://gamewith.jp/uma-musume/article/show/260740" ^
  -H "Connection: keep-alive" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain" ^
  -H "Accept: */*" ^
  -H "Origin: https://gamewith.jp" ^
  -H "Sec-Fetch-Site: cross-site" ^
  -H "Sec-Fetch-Mode: cors" ^
  -H "Sec-Fetch-Dest: empty" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "Cookie: JSESSIONID=2911db6d88cfa1eb" ^
  --data-raw "bel.7;1,6,,2gwp,15w8,5yo,'initialPageLoad,'https://gamewith.jp/uma-musume/article/show/260740,1,1,,,,4a,^!^!'f598637e-8e37-466d-9372-170347f37437,'1,blc,blc;a,'QhJSFVxMS0Q=;2,,pw,3,1,1,'GET,,'currency.prebid.org:443,'/latest.json,,,,'2,^!^!^!;2,1,2pu,2b,2,2,'POST,5k,'www.google-analytics.com:443,'/j/collect,,2,,'7,^!^!^!;2,,2s6,gh,1,,9,5k,'stats.g.doubleclick.net:443,b,,8,,'8,^!^!^!;2,1,2jw,ib,g,1,5,5k,'firebasestorage.googleapis.com:443,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FsupportCardMaster.json,,53,1,'5,^!^!^!;2,8,32n,d0,2dh2,al,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FsupportCard^%^2FsupportCard.json,,jl2,1,'9,^!^!^!;2,1,3g6,bn,2,1,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FumaMusumeMaster.json,,4z,1,'11,^!^!^!;2,1,3rv,9g,i,3,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FumaMusume^%^2FumaMusume.json,,1rg,1,'13,^!^!^!;2,1,41t,cn,2,2,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FfactorMaster.json,,4t,1,'14,^!^!^!;2,1,4ei,9l,o,2,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2Ffactor^%^2Ffactor.json,,3ln,1,'15,^!^!^!;2,1,4or,6rd,8j,3,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FskillMaster.json,,4r,1,'17,^!^!^!;2,,bon,16b,3,3,5,5k,f,'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2Fskill^%^2Fskill.json,,l19,1,'20,^!^!^!;2,,3h4,11b,1,3,9,,'firestore.googleapis.com:443,'/google.firestore.v1.Firestore/Listen/channel,go,,,'12,^!^!^!;2,,58i,5vb,1,2,9,,w,x,3p,,,'19,^!^!^!;2,,12fm,ab,,2,9,,w,x,nf,,,'29,^!^!^!;2,,15j1,23,,1,9,,w,x,3p,,,'30,^!^!^!;2,,4id,113b,,1h,5,,w,x,,,,'16,^!^!^!;2,1,15j5,2k,4,5,9,,w,x,nf,,,'31,^!^!^!;2,1,15lr,q6k,3,k,5,,w,x,,,,'32,^!^!^!;2,,1vsd,l4a,,,5,,w,x,,,,'34,^!^!^!;2,,15u9,2g,,,9,,w,x,3p,,,'33,^!^!^!;2,,2no,ky,2,1,5,5k,'firebase.googleapis.com:443,'/v1alpha/projects/-/apps/1:243679693800:web:f0d36b21b238baaeb3f25d/webConfig,,6n,1,'6,^!^!^!;2,1,2h9,2dz,7,8,5,5k,'gamewith-walkthrough-comment-api.akamaized.net:443,'/articles/260740/comments,,34a,,'4,^!^!^!;2,,4ve,689,4,4,5,5k,1a,'/articles/260740/comments/count,,r,,'18,^!^!^!;b,gn,^!,^!-gk,12,35,,q,1b,,92,s,s,11i,,p,35w,,6" ^
  --compressed &
curl "https://bam.nr-data.net/jserrors/1/31f1428de6?a=564273353&v=1208.49599aa&to=blVRYxRWWEpWVBdZC1cfcEIVQ1lUGFYRRA1aXFYYFV9ZThgd&rst=137223&ck=1&ref=https://gamewith.jp/uma-musume/article/show/260740" ^
  -H "Connection: keep-alive" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain" ^
  -H "Accept: */*" ^
  -H "Origin: https://gamewith.jp" ^
  -H "Sec-Fetch-Site: cross-site" ^
  -H "Sec-Fetch-Mode: cors" ^
  -H "Sec-Fetch-Dest: empty" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "Cookie: JSESSIONID=2911db6d88cfa1eb" ^
  --data-raw "^{^\^"xhr^\^":^[^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"bam.nr-data.net:443^\^",^\^"pathname^\^":^\^"/jserrors/1/31f1428de6^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"txSize^\^":^{^\^"t^\^":1281^},^\^"rxSize^\^":^{^\^"t^\^":24^},^\^"duration^\^":^{^\^"t^\^":864^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":76876^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"GET^\^",^\^"host^\^":^\^"firestore.googleapis.com:443^\^",^\^"pathname^\^":^\^"/google.firestore.v1.Firestore/Listen/channel^\^",^\^"status^\^":0^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"duration^\^":^{^\^"t^\^":33932^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":53919^}^}^},^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"bam.nr-data.net:443^\^",^\^"pathname^\^":^\^"/events/1/31f1428de6^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"txSize^\^":^{^\^"t^\^":2100^},^\^"rxSize^\^":^{^\^"t^\^":24^},^\^"duration^\^":^{^\^"t^\^":909^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":117224^}^}^}^],^\^"ierr^\^":^[^{^\^"params^\^":^{^\^"stackHash^\^":-153924945,^\^"exceptionClass^\^":^\^"TypeError^\^",^\^"request_uri^\^":^\^"/uma-musume/article/show/260740^\^",^\^"message^\^":^\^"Cannot convert undefined or null to object^\^",^\^"stack_trace^\^":^\^"TypeError: Cannot convert undefined or null to object^\^\n    at hasOwnProperty (^<anonymous^>)^\^\n    at r (^<inline^>:41:24705)^\^\n    at r.^<anonymous^> (^<inline^>:41:5150)^\^\n    at Object.n ^[as emit^] (^<inline^>:41:23979)^\^\n    at c (^<inline^>:41:27056)^\^\n    at Module.^<anonymous^> (https://img.gamewith.jp/gds/4.1.0/gds.min.js:7:4158)^\^\n    at Module.2b0e (https://img.gamewith.jp/gds/4.1.0/gds.min.js:7:65742)^\^\n    at i (https://img.gamewith.jp/gds/4.1.0/gds.min.js:1:415)^\^\n    at Module.5a74 (https://img.gamewith.jp/gds/4.1.0/gds.min.js:7:68991)^\^",^\^"releaseIds^\^":^\^"^{^}^\^",^\^"pageview^\^":1,^\^"browserInteractionId^\^":^\^"f598637e-8e37-466d-9372-170347f37437^\^"^},^\^"custom^\^":^{^},^\^"metrics^\^":^{^\^"count^\^":3,^\^"time^\^":^{^\^"t^\^":8411,^\^"min^\^":2231,^\^"max^\^":3090,^\^"sos^\^":24073561,^\^"c^\^":3^}^}^}^]^}" ^
  --compressed &
curl "https://bam.nr-data.net/jserrors/1/31f1428de6?a=564273353&v=1208.49599aa&to=blVRYxRWWEpWVBdZC1cfcEIVQ1lUGFYRRA1aXFYYFV9ZThgd&rst=198222&ck=1&ref=https://gamewith.jp/uma-musume/article/show/260740" ^
  -H "Connection: keep-alive" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain" ^
  -H "Accept: */*" ^
  -H "Origin: https://gamewith.jp" ^
  -H "Sec-Fetch-Site: cross-site" ^
  -H "Sec-Fetch-Mode: cors" ^
  -H "Sec-Fetch-Dest: empty" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "Cookie: JSESSIONID=2911db6d88cfa1eb" ^
  --data-raw "^{^\^"xhr^\^":^[^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"bam.nr-data.net:443^\^",^\^"pathname^\^":^\^"/jserrors/1/31f1428de6^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"txSize^\^":^{^\^"t^\^":1587^},^\^"rxSize^\^":^{^\^"t^\^":24^},^\^"duration^\^":^{^\^"t^\^":822^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":137223^}^}^}^]^}" ^
  --compressed &
curl "https://bam.nr-data.net/jserrors/1/31f1428de6?a=564273353&v=1208.49599aa&to=blVRYxRWWEpWVBdZC1cfcEIVQ1lUGFYRRA1aXFYYFV9ZThgd&rst=259223&ck=1&ref=https://gamewith.jp/uma-musume/article/show/260740" ^
  -H "Connection: keep-alive" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain" ^
  -H "Accept: */*" ^
  -H "Origin: https://gamewith.jp" ^
  -H "Sec-Fetch-Site: cross-site" ^
  -H "Sec-Fetch-Mode: cors" ^
  -H "Sec-Fetch-Dest: empty" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "Cookie: JSESSIONID=2911db6d88cfa1eb" ^
  --data-raw "^{^\^"xhr^\^":^[^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"bam.nr-data.net:443^\^",^\^"pathname^\^":^\^"/jserrors/1/31f1428de6^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"txSize^\^":^{^\^"t^\^":234^},^\^"rxSize^\^":^{^\^"t^\^":24^},^\^"duration^\^":^{^\^"t^\^":926^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":198223^}^}^}^]^}" ^
  --compressed &
curl "https://bam.nr-data.net/jserrors/1/31f1428de6?a=564273353&v=1208.49599aa&to=blVRYxRWWEpWVBdZC1cfcEIVQ1lUGFYRRA1aXFYYFV9ZThgd&rst=319226&ck=1&ref=https://gamewith.jp/uma-musume/article/show/260740" ^
  -H "Connection: keep-alive" ^
  -H "sec-ch-ua: ^\^" Not A;Brand^\^";v=^\^"99^\^", ^\^"Chromium^\^";v=^\^"90^\^", ^\^"Google Chrome^\^";v=^\^"90^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36" ^
  -H "content-type: text/plain" ^
  -H "Accept: */*" ^
  -H "Origin: https://gamewith.jp" ^
  -H "Sec-Fetch-Site: cross-site" ^
  -H "Sec-Fetch-Mode: cors" ^
  -H "Sec-Fetch-Dest: empty" ^
  -H "Referer: https://gamewith.jp/" ^
  -H "Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6" ^
  -H "Cookie: JSESSIONID=2911db6d88cfa1eb" ^
  --data-raw "^{^\^"xhr^\^":^[^{^\^"params^\^":^{^\^"method^\^":^\^"POST^\^",^\^"host^\^":^\^"bam.nr-data.net:443^\^",^\^"pathname^\^":^\^"/jserrors/1/31f1428de6^\^",^\^"status^\^":200^},^\^"metrics^\^":^{^\^"count^\^":1,^\^"txSize^\^":^{^\^"t^\^":233^},^\^"rxSize^\^":^{^\^"t^\^":24^},^\^"duration^\^":^{^\^"t^\^":865^},^\^"cbTime^\^":^{^\^"t^\^":0^},^\^"time^\^":^{^\^"t^\^":259224^}^}^}^]^}" ^
  --compressed



# cookies = {
#     'JSESSIONID': '2911db6d88cfa1eb',
# }

# headers = {
#     'authority': 'firestore.googleapis.com',
#     'sec-ch-ua': '^\\^',
#     'sec-ch-ua-mobile': '?0',
#     'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
#     'content-type': 'text/plain',
#     'accept': '*/*',
#     'origin': 'https://gamewith.jp',
#     'x-client-data': 'CIe2yQEIprbJAQjBtskBCKmdygEI+MfKAQiOncsBCKidywEIp6DLAQjc8ssBCKfzywE=',
#     'sec-fetch-site': 'cross-site',
#     'sec-fetch-mode': 'no-cors',
#     'sec-fetch-dest': 'empty',
#     'referer': 'https://gamewith.jp/',
#     'accept-language': 'en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6',
#     'Referer': 'https://gamewith.jp/',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
#     'cookie': '__Secure-3PAPISID=FzkGt7OGmii9_Sq8/Ax06TZh62AFMxURd5; ANID=AHWqTUn0VtbSrzH80mGhK04bF-5eu2dJAS2vHDBlTA-9IkFRRZJ2h08SDBfc6cU8; __Secure-3PSID=9gdneAUsSgoruYQSMMNV5h_hQgVQC28xeASOGZzTEV8rfhkJQ4bq3XDndM-4pLin3GGoGA.; NID=216=hSKTRsAIGQBsLw3DNrUQ0J8nT8rw03wSSaCpcou5HrnbtMXNDD1Ime0ZaQYRQcbiNZJsLEhBlme4OB-_4ESYDpWE8i0IFyfQ_5mT5KTzD0kr4PHUDypeGW7IJDGVP2lmEZpmFGcM3c-OZ6FUER_DBb6CZsdbgDSaXQP_MM99_GjTf7uagotCXinwqEfp_9nJ5LZdtxsXzcoSf-2JJl5clILBTKeY7erx3nr57fQa56HUT9JOSPUbZisv9e3inrhEzbz2w-S87X2bdj8m; 1P_JAR=2021-05-25-01; __Secure-3PSIDCC=AJi4QfGDxrCawbK0Te5K0SGruQ7Hw29G8FZ5S5vWVppYJSBDzbGbePgwjJE78LEXv0fZZSCPodF6',
#     'Connection': 'keep-alive',
#     'Accept': '*/*',
#     'Origin': 'https://gamewith.jp',
#     'Sec-Fetch-Site': 'cross-site',
#     'Sec-Fetch-Mode': 'cors',
#     'Sec-Fetch-Dest': 'empty',
#     'Accept-Language': 'en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,ja;q=0.6',
#     'content-length': '0',
# }

# params = (
#     ('database', 'projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)'),
#     ('VER', '8'),
#     ('gsessionid', '6E4I1OXns7l9agbpNit-L-kPzzE93HHe'),
#     ('SID', 'F_veoOLVRAfSdRiKKlKcAw'),
#     ('RID', '58633'),
#     ('AID', '204'),
#     ('zx', 'wxa3uu16yfev'),
#     ('t', '1'),
# )

# data = [
#   ('count', '1'),
#   ('count', '1'),
#   ('count', '1'),
#   ('count', '1'),
#   ('ofs', '2'),
#   ('ofs', '3'),
#   ('ofs', '4'),
#   ('ofs', '5'),
#   ('req0___data__', '^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22addTarget^%^22^%^3A^%^7B^%^22query^%^22^%^3A^%^7B^%^22structuredQuery^%^22^%^3A^%^7B^%^22from^%^22^%^3A^%^5B^%^7B^%^22collectionId^%^22^%^3A^%^22umaMusumeFriends^%^22^%^7D^%^5D^%^2C^%^22where^%^22^%^3A^%^7B^%^22fieldFilter^%^22^%^3A^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22factorIds^%^22^%^7D^%^2C^%^22op^%^22^%^3A^%^22ARRAY_CONTAINS_ANY^%^22^%^2C^%^22value^%^22^%^3A^%^7B^%^22arrayValue^%^22^%^3A^%^7B^%^22values^%^22^%^3A^%^5B^%^7B^%^22integerValue^%^22^%^3A^%^223^%^22^%^7D^%^5D^%^7D^%^7D^%^7D^%^7D^%^2C^%^22orderBy^%^22^%^3A^%^5B^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22updatedAt^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^2C^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22__name__^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^5D^%^2C^%^22limit^%^22^%^3A200^%^7D^%^2C^%^22parent^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^2Fdocuments^%^22^%^7D^%^2C^%^22targetId^%^22^%^3A4^%^7D^%^7D'),
#   ('req0___data__', '^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22removeTarget^%^22^%^3A4^%^7D'),
#   ('req0___data__', '^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22addTarget^%^22^%^3A^%^7B^%^22query^%^22^%^3A^%^7B^%^22structuredQuery^%^22^%^3A^%^7B^%^22from^%^22^%^3A^%^5B^%^7B^%^22collectionId^%^22^%^3A^%^22umaMusumeFriends^%^22^%^7D^%^5D^%^2C^%^22where^%^22^%^3A^%^7B^%^22fieldFilter^%^22^%^3A^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22factorIds^%^22^%^7D^%^2C^%^22op^%^22^%^3A^%^22ARRAY_CONTAINS_ANY^%^22^%^2C^%^22value^%^22^%^3A^%^7B^%^22arrayValue^%^22^%^3A^%^7B^%^22values^%^22^%^3A^%^5B^%^7B^%^22integerValue^%^22^%^3A^%^227^%^22^%^7D^%^5D^%^7D^%^7D^%^7D^%^7D^%^2C^%^22orderBy^%^22^%^3A^%^5B^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22updatedAt^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^2C^%^7B^%^22field^%^22^%^3A^%^7B^%^22fieldPath^%^22^%^3A^%^22__name__^%^22^%^7D^%^2C^%^22direction^%^22^%^3A^%^22DESCENDING^%^22^%^7D^%^5D^%^2C^%^22limit^%^22^%^3A200^%^7D^%^2C^%^22parent^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^2Fdocuments^%^22^%^7D^%^2C^%^22targetId^%^22^%^3A6^%^7D^%^7D'),
#   ('req0___data__', '^%^7B^%^22database^%^22^%^3A^%^22projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)^%^22^%^2C^%^22removeTarget^%^22^%^3A6^%^7D'),
#   ('^en', 'Walkthrough_Click_Event'),
#   ('_et', '6802'),
#   ('_et', '6'),
#   ('ep.name', '^%^E3^%^82^%^A6^%^E3^%^83^%^9E^%^E5^%^A8^%^98^%^E3^%^83^%^95^%^E3^%^83^%^AC^%^E3^%^83^%^B3^%^E3^%^83^%^89^%^E6^%^8E^%^B2^%^E7^%^A4^%^BA^%^E6^%^9D^%^BF'),
#   ('ep.type', '^%^E6^%^A4^%^9C^%^E7^%^B4^%^A2^%^E3^%^83^%^9C^%^E3^%^82^%^BF^%^E3^%^83^%^B3^ en=uma-friend-search'),
#   ('ep.support-card', ''),
#   ('ep.limit', ''),
#   ('ep.status', '^%^E3^%^83^%^91^%^E3^%^83^%^AF^%^E3^%^83^%^BC'),
#   ('ep.distance', '^%^E3^%^83^%^80^%^E3^%^83^%^BC^%^E3^%^83^%^88'),
#   ('ep.unique', ''),
#   ('ep.common', ''),
#   ('ep.race', ''),
#   ('ep.paging', '1'),
#   ('ep.main-umamusume', '^'),
#   ('^{^\\^xhr^\\^:^[^{^\\^params^\\^:^{^\\^method^\\^:^\\^GET^\\^,^\\^host^\\^:^\\^currency.prebid.org:443^\\^,^\\^pathname^\\^:^\\^/latest.json^\\^,^\\^status^\\^:0^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^duration^\\^:^{^\\^t^\\^:4^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:932^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^POST^\\^,^\\^host^\\^:^\\^www.google-analytics.com:443^\\^,^\\^pathname^\\^:^\\^/j/collect^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^rxSize^\\^:^{^\\^t^\\^:2^},^\\^duration^\\^:^{^\\^t^\\^:85^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:3522^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^POST^\\^,^\\^host^\\^:^\\^stats.g.doubleclick.net:443^\\^,^\\^pathname^\\^:^\\^/j/collect^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^rxSize^\\^:^{^\\^t^\\^:8^},^\\^duration^\\^:^{^\\^t^\\^:594^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:3606^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^GET^\\^,^\\^host^\\^:^\\^gamewith-walkthrough-comment-api.akamaized.net:443^\\^,^\\^pathname^\\^:^\\^/articles/260740/comments^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^rxSize^\\^:^{^\\^t^\\^:4042^},^\\^duration^\\^:^{^\\^t^\\^:3102^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:3213^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^GET^\\^,^\\^host^\\^:^\\^gamewith-walkthrough-comment-api.akamaized.net:443^\\^,^\\^pathname^\\^:^\\^/articles/260740/comments/count^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^rxSize^\\^:^{^\\^t^\\^:27^},^\\^duration^\\^:^{^\\^t^\\^:8077^},^\\^cbTime^\\^:^{^\\^t^\\^:1^},^\\^time^\\^:^{^\\^t^\\^:6314^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^POST^\\^,^\\^host^\\^:^\\^bam.nr-data.net:443^\\^,^\\^pathname^\\^:^\\^/events/1/31f1428de6^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^txSize^\\^:^{^\\^t^\\^:100^},^\\^rxSize^\\^:^{^\\^t^\\^:24^},^\\^duration^\\^:^{^\\^t^\\^:828^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:25140^}^}^}^]^}', ''),
#   ('bel.7;1,6,,2gwp,15w8,5yo,\'initialPageLoad,\'https://gamewith.jp/uma-musume/article/show/260740,1,1,,,,4a,^!^!\'f598637e-8e37-466d-9372-170347f37437,\'1,blc,blc;a,\'QhJSFVxMS0Q', ';2,,pw,3,1,1,\'GET,,\'currency.prebid.org:443,\'/latest.json,,,,\'2,^!^!^!;2,1,2pu,2b,2,2,\'POST,5k,\'www.google-analytics.com:443,\'/j/collect,,2,,\'7,^!^!^!;2,,2s6,gh,1,,9,5k,\'stats.g.doubleclick.net:443,b,,8,,\'8,^!^!^!;2,1,2jw,ib,g,1,5,5k,\'firebasestorage.googleapis.com:443,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FsupportCardMaster.json,,53,1,\'5,^!^!^!;2,8,32n,d0,2dh2,al,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FsupportCard^%^2FsupportCard.json,,jl2,1,\'9,^!^!^!;2,1,3g6,bn,2,1,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FumaMusumeMaster.json,,4z,1,\'11,^!^!^!;2,1,3rv,9g,i,3,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FumaMusume^%^2FumaMusume.json,,1rg,1,\'13,^!^!^!;2,1,41t,cn,2,2,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FfactorMaster.json,,4t,1,\'14,^!^!^!;2,1,4ei,9l,o,2,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2Ffactor^%^2Ffactor.json,,3ln,1,\'15,^!^!^!;2,1,4or,6rd,8j,3,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2FskillMaster.json,,4r,1,\'17,^!^!^!;2,,bon,16b,3,3,5,5k,f,\'/v0/b/walkthrough-tool.appspot.com/o/umaMusume^%^2Fmaster^%^2Fskill^%^2Fskill.json,,l19,1,\'20,^!^!^!;2,,3h4,11b,1,3,9,,\'firestore.googleapis.com:443,\'/google.firestore.v1.Firestore/Listen/channel,go,,,\'12,^!^!^!;2,,58i,5vb,1,2,9,,w,x,3p,,,\'19,^!^!^!;2,,12fm,ab,,2,9,,w,x,nf,,,\'29,^!^!^!;2,,15j1,23,,1,9,,w,x,3p,,,\'30,^!^!^!;2,,4id,113b,,1h,5,,w,x,,,,\'16,^!^!^!;2,1,15j5,2k,4,5,9,,w,x,nf,,,\'31,^!^!^!;2,1,15lr,q6k,3,k,5,,w,x,,,,\'32,^!^!^!;2,,1vsd,l4a,,,5,,w,x,,,,\'34,^!^!^!;2,,15u9,2g,,,9,,w,x,3p,,,\'33,^!^!^!;2,,2no,ky,2,1,5,5k,\'firebase.googleapis.com:443,\'/v1alpha/projects/-/apps/1:243679693800:web:f0d36b21b238baaeb3f25d/webConfig,,6n,1,\'6,^!^!^!;2,1,2h9,2dz,7,8,5,5k,\'gamewith-walkthrough-comment-api.akamaized.net:443,\'/articles/260740/comments,,34a,,\'4,^!^!^!;2,,4ve,689,4,4,5,5k,1a,\'/articles/260740/comments/count,,r,,\'18,^!^!^!;b,gn,^!,^!-gk,12,35,,q,1b,,92,s,s,11i,,p,35w,,6'),
#   ('^{^\\^xhr^\\^:^[^{^\\^params^\\^:^{^\\^method^\\^:^\\^POST^\\^,^\\^host^\\^:^\\^bam.nr-data.net:443^\\^,^\\^pathname^\\^:^\\^/jserrors/1/31f1428de6^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^txSize^\\^:^{^\\^t^\\^:1281^},^\\^rxSize^\\^:^{^\\^t^\\^:24^},^\\^duration^\\^:^{^\\^t^\\^:864^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:76876^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^GET^\\^,^\\^host^\\^:^\\^firestore.googleapis.com:443^\\^,^\\^pathname^\\^:^\\^/google.firestore.v1.Firestore/Listen/channel^\\^,^\\^status^\\^:0^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^duration^\\^:^{^\\^t^\\^:33932^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:53919^}^}^},^{^\\^params^\\^:^{^\\^method^\\^:^\\^POST^\\^,^\\^host^\\^:^\\^bam.nr-data.net:443^\\^,^\\^pathname^\\^:^\\^/events/1/31f1428de6^\\^,^\\^status^\\^:200^},^\\^metrics^\\^:^{^\\^count^\\^:1,^\\^txSize^\\^:^{^\\^t^\\^:2100^},^\\^rxSize^\\^:^{^\\^t^\\^:24^},^\\^duration^\\^:^{^\\^t^\\^:909^},^\\^cbTime^\\^:^{^\\^t^\\^:0^},^\\^time^\\^:^{^\\^t^\\^:117224^}^}^}^],^\\^ierr^\\^:^[^{^\\^params^\\^:^{^\\^stackHash^\\^:-153924945,^\\^exceptionClass^\\^:^\\^TypeError^\\^,^\\^request_uri^\\^:^\\^/uma-musume/article/show/260740^\\^,^\\^message^\\^:^\\^Cannot', ''),
# ]

response = requests.post('https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel', headers=headers, params=params, cookies=cookies, data=data)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.post('https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&VER=8&gsessionid=6E4I1OXns7l9agbpNit-L-kPzzE93HHe&SID=F_veoOLVRAfSdRiKKlKcAw&RID=58633&AID=204&zx=wxa3uu16yfev&t=1', headers=headers, cookies=cookies, data=data)


print(response.text)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://firestore.googleapis.com/google.firestore.v1.Firestore/Listen/channel?database=projects^%^2Fwalkthrough-tool^%^2Fdatabases^%^2F(default)&gsessionid=4_ay2mXS3puqatdK82VSbMD0cWo1xg_N&VER=8&RID=rpc&SID=3z-b5zxYq5ExuCuCgLbtXg&CI=0&AID=0&TYPE=xmlhttp&zx=d09mvw4xyza4&t=1', headers=headers)
# Out:
# <!DOCTYPE html>
# <html lang=en>
#   <meta charset=utf-8>
#   <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">
#   <title>Error 400 (Bad Request)!!1</title>
#   <style>
# ...
